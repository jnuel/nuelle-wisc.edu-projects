# %%
import os  # DELETE LATER

def create_bow(vocab, filepath):
    """ Create a single dictionary for the data
        Note: label may be None
    """
    bow = {}
    # TODO: add your code here

    return bow

def load_training_data(vocab, directory):
    """ Create the list of dictionaries """
    dataset = []
    # TODO: add your code here


    return dataset

def create_vocabulary(directory, cutoff):
    """ Create a vocabulary from the training directory
        return a sorted vocabulary list
    """

    vocab = []
    # TODO: add your code here
    # To create the vocabulary for your classifier, 
    # traverse BOTH of these subdirectories under train/ (note: do not include test/) 
    
    for folder in os.listdir(os.getcwd()):
        for filename in os.listdir(os.getcwd()):
            with open(os.path.join(os.getcwd(), folder, filename), 'r') as f: # open in readonly mode
                print(folder, filename)
      # do your stuff
        
#     f = open("demofile.txt", "r")
    # and count the number of times a word type appears in any file in either directory.

    # As a design choice, we will exclude any word types which appear at a frequency strictly less than the cutoff argument 
    # (cutoff = 1 means retain all word types you encounter). 
    # Return a sorted list of these word types.
    
    
    return vocab

def prior(training_data, label_list):
    """ return the prior probability of the label in the training set
        => frequency of DOCUMENTS
    """

    smooth = 1 # smoothing factor
    logprob = {}
    # TODO: add your code here


    return logprob

def p_word_given_label(vocab, training_data, label):
    """ return the class conditional probability of label over all words, with smoothing """
    
    smooth = 1 # smoothing factor
    word_prob = {}
    # TODO: add your code here
    
    return word_prob

    
##################################################################################
def train(training_directory, cutoff):
    """ return a dictionary formatted as follows:
            {
             'vocabulary': <the training set vocabulary>,
             'log prior': <the output of prior()>,
             'log p(w|y=2016)': <the output of p_word_given_label() for 2016>,
             'log p(w|y=2020)': <the output of p_word_given_label() for 2020>
            }
    """
    retval = {}
    # TODO: add your code here


    return retval


def classify(model, filepath):
    """ return a dictionary formatted as follows:
            {
             'predicted y': <'2016' or '2020'>, 
             'log p(y=2016|x)': <log probability of 2016 label for the document>, 
             'log p(y=2020|x)': <log probability of 2020 label for the document>
            }
    """
    retval = {}
    # TODO: add your code here


    return retval

create_vocabulary('./EasyFiles/', 1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-993e642bba8b> in <module>
#      97     return retval
#      98
# ---> 99 create_vocabulary('./EasyFiles/', 1)
#
# <ipython-input-6-993e642bba8b> in create_vocabulary(directory, cutoff)
#      30     for folder in os.listdir(os.getcwd()):
#      31         for filename in os.listdir(os.getcwd()):
# ---> 32             with open(os.path.join(os.getcwd(), folder, filename), 'r') as f: # open in readonly mode
#      33                 print(folder, filename)
#      34       # do your stuff
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/JoyNuelle/Desktop/cs540/hw4/hw4/hw4'
